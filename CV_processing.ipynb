# %%
# !pip install opencv-python
import numpy as np
import cv2
cv2.__version__
# Out:
# ...
# '4.13.0'

# %%
img=cv2.imread("/content/download (3).jpg")
print(img)
# Out:
# [[[231 231 231]
#   [231 231 231]
#   [231 231 231]
#   ...
#   [222 228 223]
#   [222 228 223]
#   [222 228 223]]
#
#  [[231 231 231]
#   [231 231 231]
#   [231 231 231]
#   ...
#   [221 227 222]
#   [221 227 222]
#   [221 227 222]]
#
#  [[231 231 231]
#   [231 231 231]
#   [231 231 231]
#   ...
#   [221 227 222]
#   [221 227 222]
#   [221 227 222]]
#
#  ...
#
#  [[213 209 214]
#   [213 209 214]
#   [213 209 214]
#   ...
#   [208 209 207]
#   [208 209 207]
#   [208 209 207]]
#
#  [[213 209 214]
#   [213 209 214]
#   [213 209 214]
#   ...
#   [208 209 207]
#   [208 209 207]
#   [208 209 207]]
#
#  [[213 209 214]
#   [213 209 214]
#   [213 209 214]
#   ...
#   [208 209 207]
#   [208 209 207]
#   [208 209 207]]]

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=736x1308>

# %%
img1=cv2.imread("/content/download (4).jpg",0)
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=L size=736x981>

# %%
cv2.imwrite("AP.jpg",img1)
# Out:
# True

# %%
print(img.size)
# Out:
# 2888064

# %%
print(img.shape)
# Out:
# (1308, 736, 3)

# %%
print(img.dtype)
# Out:
# uint8

# %%
img2=img[30:800,20:300]
img2
# Out:
# array([[[230, 227, 229],
#         [230, 227, 229],
#         [230, 227, 229],
#         ...,
#         [222, 222, 222],
#         [224, 224, 224],
#         [224, 224, 224]],
#
#        [[230, 227, 229],
#         [230, 227, 229],
#         [230, 227, 229],
#         ...,
#         [223, 223, 223],
#         [224, 224, 224],
#         [224, 224, 224]],
#
#        [[229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        ...,
#
#        [[211, 217, 212],
#         [210, 216, 211],
#         [213, 216, 214],
#         ...,
#         [ 67,  67,  67],
#         [ 39,  39,  39],
#         [ 21,  21,  21]],
#
#        [[210, 216, 211],
#         [210, 216, 211],
#         [213, 216, 214],
#         ...,
#         [144, 144, 144],
#         [ 50,  50,  50],
#         [ 22,  22,  22]],
#
#        [[210, 216, 211],
#         [210, 216, 211],
#         [213, 216, 214],
# ...

# %%
img3=cv2.rotate(img,cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(img3)
img3=cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
cv2_imshow(img3)
img3=cv2.rotate(img,cv2.ROTATE_180)
cv2_imshow(img3)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
img4=cv2.flip(img,0)
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=736x1308>

# %%
img4=cv2.flip(img,1)
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=736x1308>

# %%
img4=cv2.flip(img,-1)
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=736x1308>

# %%
img5=cv2.resize(img,(300,300))
cv2_imshow(img5)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
img6=cv2.blur(img5,(1,50))
cv2_imshow(img6)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
