# %%
# !pip install opencv-python
import numpy as np
import cv2
cv2.__version__
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# '4.13.0'

# %%
img=cv2.imread('/content/Adorable German Shepherd Puppy 🐶 _ Natural Realistic Puppy Reel.jpg')
print(img)
# Out:
# [[[ 65 118 108]
#   [ 66 119 109]
#   [ 66 122 111]
#   ...
#   [121 117 116]
#   [121 117 116]
#   [122 118 117]]
#
#  [[ 65 118 108]
#   [ 66 119 109]
#   [ 68 121 111]
#   ...
#   [121 117 116]
#   [121 117 116]
#   [122 118 117]]
#
#  [[ 66 117 109]
#   [ 66 119 110]
#   [ 68 121 112]
#   ...
#   [121 117 116]
#   [121 117 116]
#   [122 118 117]]
#
#  ...
#
#  [[128 141 157]
#   [129 142 158]
#   [141 154 170]
#   ...
#   [125 132 147]
#   [122 129 144]
#   [125 132 147]]
#
#  [[121 134 150]
#   [125 138 154]
#   [142 155 171]
#   ...
#   [104 111 126]
#   [100 107 122]
#   [107 114 129]]
#
#  [[123 136 152]
#   [128 141 157]
#   [147 160 176]
#   ...
#   [ 85  92 107]
#   [ 83  90 105]
#   [ 93 100 115]]]

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
edges=cv2.Canny(gray_img,50,150)

# %%
img.shape
# Out:
# (1307, 736, 3)

# %%
img=cv2.resize(img,(300,300))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2_imshow(gray_img)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
